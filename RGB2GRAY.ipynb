# %%
import cv2
import numpy as np
import sys
import os
from os import path
import time
from concurrent.futures import ThreadPoolExecutor

# %%
danalab_path = '/tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab'
data_folders = os.listdir(danalab_path)
RGB_folders = [path.join(danalab_path, folder, 'RGB') for folder in data_folders if path.isdir(path.join(danalab_path, folder, 'RGB'))]

# %%
def process_image(img_path, new_img_path, three_channel=True):
    if path.exists(new_img_path):
        return
    img = cv2.imread(img_path)
    # BGR 이미지를 그레이스케일로 변환
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    if three_channel:
        # 단일 채널 그레이스케일 이미지를 3채널로 변환
        gray_img = cv2.cvtColor(gray_img, cv2.COLOR_GRAY2BGR)
    
    cv2.imwrite(new_img_path, gray_img)
    print('Saved:', new_img_path)

def process_folder(cover_path, new_cover_path, three_channel=True):
    if not path.exists(new_cover_path):
        os.mkdir(new_cover_path)
    with ThreadPoolExecutor() as executor:
        for img_name in os.listdir(cover_path):
            img_path = path.join(cover_path, img_name)
            new_img_path = path.join(new_cover_path, img_name)
            executor.submit(process_image, img_path, new_img_path, three_channel)
    print('Done:', new_cover_path)

def process_rgb_folder(RGB_folder, three_channel=True):
    new_path = RGB_folder + '2GRAY_3C'
    if not path.exists(new_path):
        os.mkdir(new_path)
    with ThreadPoolExecutor() as executor:
        for cover_folder in os.listdir(RGB_folder):
            cover_path = path.join(RGB_folder, cover_folder)
            new_cover_path = path.join(new_path, cover_folder)
            executor.submit(process_folder, cover_path, new_cover_path, three_channel)

for RGB_folder in RGB_folders:
    # True로 설정하면 3채널 그레이스케일, False로 설정하면 1채널 그레이스케일
    process_rgb_folder(RGB_folder, three_channel=True)
# Out:
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000028.png
# Saved:Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000031.png
#   /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000040.png
# Saved: Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000034.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000041.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000028.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000040.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000028.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000017.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000017.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000015.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000023.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000012.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000034.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000002.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000008.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000022.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000040.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000039.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000007.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000008.png
#
# Saved: Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000023.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000022.png
# Saved: Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000007.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000015.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000002.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000002.png
# Saved: Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000015.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000004.pngSaved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000031.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000021.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000023.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000030.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000012.png
# Saved:Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000006.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000035.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000045.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000016.png
#  Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000016.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000013.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000021.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000045.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000021.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000043.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000013.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000027.png
# Saved:Saved:Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000043.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000003.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000020.png
#  Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000042.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000003.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000013.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000003.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000024.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000007.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000008.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000024.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000012.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000016.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000004.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000031.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000022.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000004.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000043.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000006.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000045.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000034.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover/image_000006.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/uncover
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1/image_000033.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover1
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2/image_000024.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00064/RGB2GRAY_3C/cover2
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000012.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000031.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000031.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000025.png
#  Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000040.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000034.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000004.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000028.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000015.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000040.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000007.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000004.png
#  Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000006.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000008.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000040.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000028.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000022.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000002.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000022.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000045.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000021.png
# Saved: Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000023.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000021.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000016.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000021.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000006.png /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000030.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000013.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000003.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000016.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000043.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000013.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000022.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000034.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000007.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000004.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000015.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000015.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000012.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000006.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000003.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000036.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000016.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000045.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000043.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000008.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000024.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000028.png
# Saved: Saved:/tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000043.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000003.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000013.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000002.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000031.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000034.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000008.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000007.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000002.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000012.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000024.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1/image_000025.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover1
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000045.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000024.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2/image_000041.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/cover2
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover/image_000035.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00083/RGB2GRAY_3C/uncover
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000015.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000009.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000015.png
# Saved: Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000002.png
#  Saved:Saved: Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000012.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000034.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000004.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000028.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000008.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000011.png
#  Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000006.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000004.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000002.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000025.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000002.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000028.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000045.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000022.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000004.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000022.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000021.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000022.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000008.png
# Saved:Saved:  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000033.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000006.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000013.pngSaved:
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000042.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000027.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000037.png
# Saved:Saved:  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000044.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000045.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000016.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000003.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000006.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000043.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000043.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000024.png
# Saved:Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000038.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000013.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000003.png
# Saved:Saved:Saved:  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000020.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000024.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000003.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000028.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000034.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000040.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000031.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000045.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000012.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000007.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000040.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000013.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000034.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000007.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000031.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000015.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000031.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000040.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000012.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000007.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000016.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000021.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000021.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000008.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000024.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1/image_000016.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover1
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2/image_000043.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/cover2
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover/image_000005.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00085/RGB2GRAY_3C/uncover
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000040.png
# Saved: Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000034.png/tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000040.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000008.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000002.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000025.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000012.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000015.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000008.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000040.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000028.png
# Saved:
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000032.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000039.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000007.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000022.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000033.png
#  Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000031.png
# Saved: Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000010.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000005.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000034.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000015.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000018.png
# Saved:Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000006.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000008.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000019.png
#   Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000044.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000045.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000045.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000021.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000006.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000037.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000035.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000044.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover1/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000021.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000017.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000024.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000016.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000013.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/uncover/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00012/RGB2GRAY_3C/cover2/image_000026.png
# ...
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/uncover/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/uncover/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/uncover/image_000034.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover2/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover2/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000004.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000021.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover2/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/uncover/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/uncover/image_000029.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/uncover
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover2/image_000045.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover2/image_000011.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover2
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1/image_000024.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00073/RGB2GRAY_3C/cover1
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000040.pngSaved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000040.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000002.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000022.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000012.png
#  Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000028.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000034.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000009.png
# Saved: Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000012.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000002.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000008.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000008.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000031.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000025.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000034.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000002.png
# /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000004.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000008.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000010.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000015.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000032.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000007.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000028.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000010.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000004.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000039.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000045.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000018.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000022.png
#
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000021.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000033.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000045.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000035.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000021.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000016.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000003.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000013.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000036.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000043.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000029.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000024.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000013.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000043.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000043.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000034.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000015.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000014.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000024.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000003.png
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000014.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000041.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000004.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000027.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000015.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000006.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000040.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000013.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000007.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000031.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000024.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000037.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000010.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000001.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000044.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000016.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000019.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000016.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000018.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000009.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000030.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000026.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000005.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000039.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000032.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000012.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000038.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000017.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000028.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000011.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000031.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000023.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000006.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000020.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000022.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000006.pngSaved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000042.png
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1/image_000007.png
#
# Saved:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000021.pngDone:Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000037.png
#
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000045.png
#  /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover1
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover/image_000001.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/uncover
# Saved: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2/image_000003.png
# Done: /tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/00056/RGB2GRAY_3C/cover2

# %%
# 기본 경로 설정
base_path = "/tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/"

# 기본 경로가 존재하는지 확인
if not os.path.exists(base_path):
    print(f"경로가 존재하지 않습니다: {base_path}")
else:
    # 기본 경로 내의 모든 폴더 순회
    for subject_dir in os.listdir(base_path):
        subject_path = os.path.join(base_path, subject_dir)
        
        # 디렉토리인지 확인
        if os.path.isdir(subject_path):
            print(f"폴더 처리 중: {subject_dir}")
            
            # RGB 폴더가 존재하는지 확인하고 RGB_real로 이름 변경
            rgb_path = os.path.join(subject_path, "RGB")
            rgb_real_path = os.path.join(subject_path, "RGB_real")
            
            if os.path.exists(rgb_path) and not os.path.exists(rgb_real_path):
                try:
                    os.rename(rgb_path, rgb_real_path)
                    print(f"  {subject_dir}/RGB → {subject_dir}/RGB_real 이름 변경 완료")
                except Exception as e:
                    print(f"  {subject_dir}/RGB → {subject_dir}/RGB_real 이름 변경 실패: {e}")
            elif os.path.exists(rgb_real_path):
                print(f"  {subject_dir}/RGB_real 이미 존재함")
            else:
                print(f"  {subject_dir}/RGB 폴더가 없음")
            
            # RGB2GRAY 폴더가 존재하는지 확인하고 RGB로 이름 변경
            rgb2gray_path = os.path.join(subject_path, "RGB2GRAY_3C")
            new_rgb_path = os.path.join(subject_path, "RGB")
            
            if os.path.exists(rgb2gray_path) and not os.path.exists(new_rgb_path):
                try:
                    os.rename(rgb2gray_path, new_rgb_path)
                    print(f"  {subject_dir}/RGB2GRAY → {subject_dir}/RGB 이름 변경 완료")
                except Exception as e:
                    print(f"  {subject_dir}/RGB2GRAY → {subject_dir}/RGB 이름 변경 실패: {e}")
            elif os.path.exists(new_rgb_path):
                print(f"  {subject_dir}/RGB 이미 존재함 (RGB2GRAY를 변환할 수 없음)")
            else:
                print(f"  {subject_dir}/RGB2GRAY 폴더가 없음")

    print("모든 폴더 처리 완료")
# Out:
# 폴더 처리 중: 00064
#   00064/RGB → 00064/RGB_real 이름 변경 완료
#   00064/RGB2GRAY → 00064/RGB 이름 변경 완료
# 폴더 처리 중: 00083
#   00083/RGB → 00083/RGB_real 이름 변경 완료
#   00083/RGB2GRAY → 00083/RGB 이름 변경 완료
# 폴더 처리 중: 00085
#   00085/RGB → 00085/RGB_real 이름 변경 완료
#   00085/RGB2GRAY → 00085/RGB 이름 변경 완료
# 폴더 처리 중: 00012
#   00012/RGB → 00012/RGB_real 이름 변경 완료
#   00012/RGB2GRAY → 00012/RGB 이름 변경 완료
# 폴더 처리 중: 00038
#   00038/RGB → 00038/RGB_real 이름 변경 완료
#   00038/RGB2GRAY → 00038/RGB 이름 변경 완료
# 폴더 처리 중: 00044
#   00044/RGB → 00044/RGB_real 이름 변경 완료
#   00044/RGB2GRAY → 00044/RGB 이름 변경 완료
# 폴더 처리 중: 00097
#   00097/RGB → 00097/RGB_real 이름 변경 완료
#   00097/RGB2GRAY → 00097/RGB 이름 변경 완료
# 폴더 처리 중: 00045
#   00045/RGB → 00045/RGB_real 이름 변경 완료
#   00045/RGB2GRAY → 00045/RGB 이름 변경 완료
# 폴더 처리 중: 00063
#   00063/RGB → 00063/RGB_real 이름 변경 완료
#   00063/RGB2GRAY → 00063/RGB 이름 변경 완료
# 폴더 처리 중: 00070
#   00070/RGB → 00070/RGB_real 이름 변경 완료
#   00070/RGB2GRAY → 00070/RGB 이름 변경 완료
# 폴더 처리 중: 00075
#   00075/RGB → 00075/RGB_real 이름 변경 완료
#   00075/RGB2GRAY → 00075/RGB 이름 변경 완료
# 폴더 처리 중: 00042
#   00042/RGB → 00042/RGB_real 이름 변경 완료
#   00042/RGB2GRAY → 00042/RGB 이름 변경 완료
# 폴더 처리 중: 00101
#   00101/RGB → 00101/RGB_real 이름 변경 완료
#   00101/RGB2GRAY → 00101/RGB 이름 변경 완료
# 폴더 처리 중: 00020
#   00020/RGB → 00020/RGB_real 이름 변경 완료
#   00020/RGB2GRAY → 00020/RGB 이름 변경 완료
# 폴더 처리 중: 00058
#   00058/RGB → 00058/RGB_real 이름 변경 완료
#   00058/RGB2GRAY → 00058/RGB 이름 변경 완료
# 폴더 처리 중: 00100
#   00100/RGB → 00100/RGB_real 이름 변경 완료
#   00100/RGB2GRAY → 00100/RGB 이름 변경 완료
# 폴더 처리 중: 00091
#   00091/RGB → 00091/RGB_real 이름 변경 완료
#   00091/RGB2GRAY → 00091/RGB 이름 변경 완료
# 폴더 처리 중: 00102
#   00102/RGB → 00102/RGB_real 이름 변경 완료
#   00102/RGB2GRAY → 00102/RGB 이름 변경 완료
# 폴더 처리 중: 00017
#   00017/RGB → 00017/RGB_real 이름 변경 완료
#   00017/RGB2GRAY → 00017/RGB 이름 변경 완료
# 폴더 처리 중: 00049
#   00049/RGB → 00049/RGB_real 이름 변경 완료
#   00049/RGB2GRAY → 00049/RGB 이름 변경 완료
# 폴더 처리 중: 00071
#   00071/RGB → 00071/RGB_real 이름 변경 완료
#   00071/RGB2GRAY → 00071/RGB 이름 변경 완료
# 폴더 처리 중: 00022
#   00022/RGB → 00022/RGB_real 이름 변경 완료
#   00022/RGB2GRAY → 00022/RGB 이름 변경 완료
# 폴더 처리 중: 00081
#   00081/RGB → 00081/RGB_real 이름 변경 완료
#   00081/RGB2GRAY → 00081/RGB 이름 변경 완료
# 폴더 처리 중: 00032
#   00032/RGB → 00032/RGB_real 이름 변경 완료
#   00032/RGB2GRAY → 00032/RGB 이름 변경 완료
# 폴더 처리 중: 00002
#   00002/RGB → 00002/RGB_real 이름 변경 완료
#   00002/RGB2GRAY → 00002/RGB 이름 변경 완료
# 폴더 처리 중: 00027
#   00027/RGB → 00027/RGB_real 이름 변경 완료
#   00027/RGB2GRAY → 00027/RGB 이름 변경 완료
# 폴더 처리 중: 00079
#   00079/RGB → 00079/RGB_real 이름 변경 완료
#   00079/RGB2GRAY → 00079/RGB 이름 변경 완료
# 폴더 처리 중: 00092
#   00092/RGB → 00092/RGB_real 이름 변경 완료
#   00092/RGB2GRAY → 00092/RGB 이름 변경 완료
# 폴더 처리 중: 00061
#   00061/RGB → 00061/RGB_real 이름 변경 완료
#   00061/RGB2GRAY → 00061/RGB 이름 변경 완료
# 폴더 처리 중: 00048
#   00048/RGB → 00048/RGB_real 이름 변경 완료
#   00048/RGB2GRAY → 00048/RGB 이름 변경 완료
# 폴더 처리 중: 00055
#   00055/RGB → 00055/RGB_real 이름 변경 완료
#   00055/RGB2GRAY → 00055/RGB 이름 변경 완료
# 폴더 처리 중: 00009
#   00009/RGB → 00009/RGB_real 이름 변경 완료
#   00009/RGB2GRAY → 00009/RGB 이름 변경 완료
# 폴더 처리 중: 00057
#   00057/RGB → 00057/RGB_real 이름 변경 완료
#   00057/RGB2GRAY → 00057/RGB 이름 변경 완료
# 폴더 처리 중: 00053
#   00053/RGB → 00053/RGB_real 이름 변경 완료
#   00053/RGB2GRAY → 00053/RGB 이름 변경 완료
# 폴더 처리 중: 00018
#   00018/RGB → 00018/RGB_real 이름 변경 완료
#   00018/RGB2GRAY → 00018/RGB 이름 변경 완료
# 폴더 처리 중: 00037
#   00037/RGB → 00037/RGB_real 이름 변경 완료
#   00037/RGB2GRAY → 00037/RGB 이름 변경 완료
# 폴더 처리 중: 00082
#   00082/RGB → 00082/RGB_real 이름 변경 완료
#   00082/RGB2GRAY → 00082/RGB 이름 변경 완료
# 폴더 처리 중: 00035
#   00035/RGB → 00035/RGB_real 이름 변경 완료
#   00035/RGB2GRAY → 00035/RGB 이름 변경 완료
# 폴더 처리 중: 00010
#   00010/RGB → 00010/RGB_real 이름 변경 완료
#   00010/RGB2GRAY → 00010/RGB 이름 변경 완료
# 폴더 처리 중: 00015
#   00015/RGB → 00015/RGB_real 이름 변경 완료
#   00015/RGB2GRAY → 00015/RGB 이름 변경 완료
# 폴더 처리 중: 00016
#   00016/RGB → 00016/RGB_real 이름 변경 완료
#   00016/RGB2GRAY → 00016/RGB 이름 변경 완료
# 폴더 처리 중: 00052
#   00052/RGB → 00052/RGB_real 이름 변경 완료
#   00052/RGB2GRAY → 00052/RGB 이름 변경 완료
# 폴더 처리 중: 00019
#   00019/RGB → 00019/RGB_real 이름 변경 완료
#   00019/RGB2GRAY → 00019/RGB 이름 변경 완료
# 폴더 처리 중: 00046
#   00046/RGB → 00046/RGB_real 이름 변경 완료
#   00046/RGB2GRAY → 00046/RGB 이름 변경 완료
# 폴더 처리 중: 00034
#   00034/RGB → 00034/RGB_real 이름 변경 완료
#   00034/RGB2GRAY → 00034/RGB 이름 변경 완료
# 폴더 처리 중: 00024
#   00024/RGB → 00024/RGB_real 이름 변경 완료
#   00024/RGB2GRAY → 00024/RGB 이름 변경 완료
# 폴더 처리 중: 00026
#   00026/RGB → 00026/RGB_real 이름 변경 완료
#   00026/RGB2GRAY → 00026/RGB 이름 변경 완료
# 폴더 처리 중: 00090
#   00090/RGB → 00090/RGB_real 이름 변경 완료
#   00090/RGB2GRAY → 00090/RGB 이름 변경 완료
# 폴더 처리 중: 00036
#   00036/RGB → 00036/RGB_real 이름 변경 완료
#   00036/RGB2GRAY → 00036/RGB 이름 변경 완료
# 폴더 처리 중: 00029
#   00029/RGB → 00029/RGB_real 이름 변경 완료
#   00029/RGB2GRAY → 00029/RGB 이름 변경 완료
# 폴더 처리 중: 00030
#   00030/RGB → 00030/RGB_real 이름 변경 완료
#   00030/RGB2GRAY → 00030/RGB 이름 변경 완료
# 폴더 처리 중: 00001
#   00001/RGB → 00001/RGB_real 이름 변경 완료
#   00001/RGB2GRAY → 00001/RGB 이름 변경 완료
# 폴더 처리 중: 00069
#   00069/RGB → 00069/RGB_real 이름 변경 완료
#   00069/RGB2GRAY → 00069/RGB 이름 변경 완료
# 폴더 처리 중: 00087
#   00087/RGB → 00087/RGB_real 이름 변경 완료
#   00087/RGB2GRAY → 00087/RGB 이름 변경 완료
# 폴더 처리 중: 00093
#   00093/RGB → 00093/RGB_real 이름 변경 완료
#   00093/RGB2GRAY → 00093/RGB 이름 변경 완료
# 폴더 처리 중: 00004
#   00004/RGB → 00004/RGB_real 이름 변경 완료
#   00004/RGB2GRAY → 00004/RGB 이름 변경 완료
# 폴더 처리 중: 00059
#   00059/RGB → 00059/RGB_real 이름 변경 완료
#   00059/RGB2GRAY → 00059/RGB 이름 변경 완료
# 폴더 처리 중: 00047
#   00047/RGB → 00047/RGB_real 이름 변경 완료
#   00047/RGB2GRAY → 00047/RGB 이름 변경 완료
# 폴더 처리 중: 00011
#   00011/RGB → 00011/RGB_real 이름 변경 완료
#   00011/RGB2GRAY → 00011/RGB 이름 변경 완료
# 폴더 처리 중: 00066
#   00066/RGB → 00066/RGB_real 이름 변경 완료
#   00066/RGB2GRAY → 00066/RGB 이름 변경 완료
# 폴더 처리 중: 00065
#   00065/RGB → 00065/RGB_real 이름 변경 완료
#   00065/RGB2GRAY → 00065/RGB 이름 변경 완료
# 폴더 처리 중: 00025
#   00025/RGB → 00025/RGB_real 이름 변경 완료
#   00025/RGB2GRAY → 00025/RGB 이름 변경 완료
# 폴더 처리 중: 00054
#   00054/RGB → 00054/RGB_real 이름 변경 완료
#   00054/RGB2GRAY → 00054/RGB 이름 변경 완료
# 폴더 처리 중: 00060
#   00060/RGB → 00060/RGB_real 이름 변경 완료
#   00060/RGB2GRAY → 00060/RGB 이름 변경 완료
# 폴더 처리 중: 00094
#   00094/RGB → 00094/RGB_real 이름 변경 완료
#   00094/RGB2GRAY → 00094/RGB 이름 변경 완료
# 폴더 처리 중: 00086
#   00086/RGB → 00086/RGB_real 이름 변경 완료
#   00086/RGB2GRAY → 00086/RGB 이름 변경 완료
# 폴더 처리 중: 00068
#   00068/RGB → 00068/RGB_real 이름 변경 완료
#   00068/RGB2GRAY → 00068/RGB 이름 변경 완료
# 폴더 처리 중: 00043
#   00043/RGB → 00043/RGB_real 이름 변경 완료
#   00043/RGB2GRAY → 00043/RGB 이름 변경 완료
# 폴더 처리 중: 00040
#   00040/RGB → 00040/RGB_real 이름 변경 완료
#   00040/RGB2GRAY → 00040/RGB 이름 변경 완료
# 폴더 처리 중: 00076
#   00076/RGB → 00076/RGB_real 이름 변경 완료
#   00076/RGB2GRAY → 00076/RGB 이름 변경 완료
# 폴더 처리 중: 00072
#   00072/RGB → 00072/RGB_real 이름 변경 완료
#   00072/RGB2GRAY → 00072/RGB 이름 변경 완료
# 폴더 처리 중: 00007
#   00007/RGB → 00007/RGB_real 이름 변경 완료
#   00007/RGB2GRAY → 00007/RGB 이름 변경 완료
# 폴더 처리 중: 00039
#   00039/RGB → 00039/RGB_real 이름 변경 완료
#   00039/RGB2GRAY → 00039/RGB 이름 변경 완료
# 폴더 처리 중: 00078
#   00078/RGB → 00078/RGB_real 이름 변경 완료
#   00078/RGB2GRAY → 00078/RGB 이름 변경 완료
# 폴더 처리 중: 00099
#   00099/RGB → 00099/RGB_real 이름 변경 완료
#   00099/RGB2GRAY → 00099/RGB 이름 변경 완료
# 폴더 처리 중: 00096
#   00096/RGB → 00096/RGB_real 이름 변경 완료
#   00096/RGB2GRAY → 00096/RGB 이름 변경 완료
# 폴더 처리 중: 00088
#   00088/RGB → 00088/RGB_real 이름 변경 완료
#   00088/RGB2GRAY → 00088/RGB 이름 변경 완료
# 폴더 처리 중: 00031
#   00031/RGB → 00031/RGB_real 이름 변경 완료
#   00031/RGB2GRAY → 00031/RGB 이름 변경 완료
# 폴더 처리 중: 00098
#   00098/RGB → 00098/RGB_real 이름 변경 완료
#   00098/RGB2GRAY → 00098/RGB 이름 변경 완료
# 폴더 처리 중: 00008
#   00008/RGB → 00008/RGB_real 이름 변경 완료
#   00008/RGB2GRAY → 00008/RGB 이름 변경 완료
# 폴더 처리 중: 00014
#   00014/RGB → 00014/RGB_real 이름 변경 완료
#   00014/RGB2GRAY → 00014/RGB 이름 변경 완료
# 폴더 처리 중: 00062
#   00062/RGB → 00062/RGB_real 이름 변경 완료
#   00062/RGB2GRAY → 00062/RGB 이름 변경 완료
# 폴더 처리 중: 00003
#   00003/RGB → 00003/RGB_real 이름 변경 완료
#   00003/RGB2GRAY → 00003/RGB 이름 변경 완료
# 폴더 처리 중: 00080
#   00080/RGB → 00080/RGB_real 이름 변경 완료
#   00080/RGB2GRAY → 00080/RGB 이름 변경 완료
# 폴더 처리 중: 00084
#   00084/RGB → 00084/RGB_real 이름 변경 완료
#   00084/RGB2GRAY → 00084/RGB 이름 변경 완료
# 폴더 처리 중: 00005
#   00005/RGB → 00005/RGB_real 이름 변경 완료
#   00005/RGB2GRAY → 00005/RGB 이름 변경 완료
# 폴더 처리 중: 00033
#   00033/RGB → 00033/RGB_real 이름 변경 완료
#   00033/RGB2GRAY → 00033/RGB 이름 변경 완료
# 폴더 처리 중: 00006
#   00006/RGB → 00006/RGB_real 이름 변경 완료
#   00006/RGB2GRAY → 00006/RGB 이름 변경 완료
# 폴더 처리 중: 00095
#   00095/RGB → 00095/RGB_real 이름 변경 완료
#   00095/RGB2GRAY → 00095/RGB 이름 변경 완료
# 폴더 처리 중: 00077
#   00077/RGB → 00077/RGB_real 이름 변경 완료
#   00077/RGB2GRAY → 00077/RGB 이름 변경 완료
# 폴더 처리 중: 00028
#   00028/RGB → 00028/RGB_real 이름 변경 완료
#   00028/RGB2GRAY → 00028/RGB 이름 변경 완료
# 폴더 처리 중: 00050
#   00050/RGB → 00050/RGB_real 이름 변경 완료
#   00050/RGB2GRAY → 00050/RGB 이름 변경 완료
# 폴더 처리 중: 00074
#   00074/RGB → 00074/RGB_real 이름 변경 완료
#   00074/RGB2GRAY → 00074/RGB 이름 변경 완료
# 폴더 처리 중: 00013
#   00013/RGB → 00013/RGB_real 이름 변경 완료
#   00013/RGB2GRAY → 00013/RGB 이름 변경 완료
# 폴더 처리 중: 00067
#   00067/RGB → 00067/RGB_real 이름 변경 완료
#   00067/RGB2GRAY → 00067/RGB 이름 변경 완료
# 폴더 처리 중: 00023
#   00023/RGB → 00023/RGB_real 이름 변경 완료
#   00023/RGB2GRAY → 00023/RGB 이름 변경 완료
# 폴더 처리 중: 00051
#   00051/RGB → 00051/RGB_real 이름 변경 완료
#   00051/RGB2GRAY → 00051/RGB 이름 변경 완료
# 폴더 처리 중: 00021
#   00021/RGB → 00021/RGB_real 이름 변경 완료
#   00021/RGB2GRAY → 00021/RGB 이름 변경 완료
# 폴더 처리 중: 00089
#   00089/RGB → 00089/RGB_real 이름 변경 완료
#   00089/RGB2GRAY → 00089/RGB 이름 변경 완료
# 폴더 처리 중: 00041
#   00041/RGB → 00041/RGB_real 이름 변경 완료
#   00041/RGB2GRAY → 00041/RGB 이름 변경 완료
# 폴더 처리 중: 00073
#   00073/RGB → 00073/RGB_real 이름 변경 완료
#   00073/RGB2GRAY → 00073/RGB 이름 변경 완료
# 폴더 처리 중: 00056
#   00056/RGB → 00056/RGB_real 이름 변경 완료
#   00056/RGB2GRAY → 00056/RGB 이름 변경 완료
# 모든 폴더 처리 완료

# %%
import os
import shutil

# 기본 경로 설정
base_path = "/tf/02_code/SLP-Dataset-and-Code/data/SLP/danaLab/"

# 기본 경로가 존재하는지 확인
if not os.path.exists(base_path):
    print(f"경로가 존재하지 않습니다: {base_path}")
else:
    # 기본 경로 내의 모든 폴더 순회
    for subject_dir in os.listdir(base_path):
        subject_path = os.path.join(base_path, subject_dir)
        
        # 디렉토리인지 확인
        if os.path.isdir(subject_path):
            print(f"폴더 처리 중: {subject_dir}")
            
            # 먼저 현재 RGB 폴더가 있다면(이전에 RGB2GRAY였던 폴더) 이를 임시 이름으로 변경
            # 이렇게 하면 이름 충돌을 방지할 수 있음
            rgb_path = os.path.join(subject_path, "RGB")
            rgb_temp_path = os.path.join(subject_path, "RGB_temp")
            
            if os.path.exists(rgb_path):
                try:
                    os.rename(rgb_path, rgb_temp_path)
                    print(f"  {subject_dir}/RGB → {subject_dir}/RGB_temp 임시 이름 변경 완료")
                except Exception as e:
                    print(f"  {subject_dir}/RGB → {subject_dir}/RGB_temp 이름 변경 실패: {e}")
                    continue  # 이 폴더에 대한 작업 중단
            
            # RGB_real 폴더가 존재하는지 확인하고 RGB로 이름 변경
            rgb_real_path = os.path.join(subject_path, "RGB_real")
            new_rgb_path = os.path.join(subject_path, "RGB")
            
            if os.path.exists(rgb_real_path):
                try:
                    os.rename(rgb_real_path, new_rgb_path)
                    print(f"  {subject_dir}/RGB_real → {subject_dir}/RGB 이름 변경 완료")
                except Exception as e:
                    print(f"  {subject_dir}/RGB_real → {subject_dir}/RGB 이름 변경 실패: {e}")
            else:
                print(f"  {subject_dir}/RGB_real 폴더가 없음")
            
            # 임시 RGB 폴더(이전에 RGB2GRAY였던 폴더)를 RGB2GRAY로 이름 변경
            if os.path.exists(rgb_temp_path):
                rgb2gray_path = os.path.join(subject_path, "RGB2GRAY")
                try:
                    os.rename(rgb_temp_path, rgb2gray_path)
                    print(f"  {subject_dir}/RGB_temp → {subject_dir}/RGB2GRAY 이름 변경 완료")
                except Exception as e:
                    print(f"  {subject_dir}/RGB_temp → {subject_dir}/RGB2GRAY 이름 변경 실패: {e}")

    print("모든 폴더 원상복구 완료")
# Out:
# 폴더 처리 중: 00064
#   00064/RGB → 00064/RGB_temp 임시 이름 변경 완료
#   00064/RGB_real → 00064/RGB 이름 변경 완료
#   00064/RGB_temp → 00064/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00083
#   00083/RGB → 00083/RGB_temp 임시 이름 변경 완료
#   00083/RGB_real → 00083/RGB 이름 변경 완료
#   00083/RGB_temp → 00083/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00085
#   00085/RGB → 00085/RGB_temp 임시 이름 변경 완료
#   00085/RGB_real → 00085/RGB 이름 변경 완료
#   00085/RGB_temp → 00085/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00012
#   00012/RGB → 00012/RGB_temp 임시 이름 변경 완료
#   00012/RGB_real → 00012/RGB 이름 변경 완료
#   00012/RGB_temp → 00012/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00038
#   00038/RGB → 00038/RGB_temp 임시 이름 변경 완료
#   00038/RGB_real → 00038/RGB 이름 변경 완료
#   00038/RGB_temp → 00038/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00044
#   00044/RGB → 00044/RGB_temp 임시 이름 변경 완료
#   00044/RGB_real → 00044/RGB 이름 변경 완료
#   00044/RGB_temp → 00044/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00097
#   00097/RGB → 00097/RGB_temp 임시 이름 변경 완료
#   00097/RGB_real → 00097/RGB 이름 변경 완료
#   00097/RGB_temp → 00097/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00045
#   00045/RGB → 00045/RGB_temp 임시 이름 변경 완료
#   00045/RGB_real → 00045/RGB 이름 변경 완료
#   00045/RGB_temp → 00045/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00063
#   00063/RGB → 00063/RGB_temp 임시 이름 변경 완료
#   00063/RGB_real → 00063/RGB 이름 변경 완료
#   00063/RGB_temp → 00063/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00070
#   00070/RGB → 00070/RGB_temp 임시 이름 변경 완료
#   00070/RGB_real → 00070/RGB 이름 변경 완료
#   00070/RGB_temp → 00070/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00075
#   00075/RGB → 00075/RGB_temp 임시 이름 변경 완료
#   00075/RGB_real → 00075/RGB 이름 변경 완료
#   00075/RGB_temp → 00075/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00042
#   00042/RGB → 00042/RGB_temp 임시 이름 변경 완료
#   00042/RGB_real → 00042/RGB 이름 변경 완료
#   00042/RGB_temp → 00042/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00101
#   00101/RGB → 00101/RGB_temp 임시 이름 변경 완료
#   00101/RGB_real → 00101/RGB 이름 변경 완료
#   00101/RGB_temp → 00101/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00020
#   00020/RGB → 00020/RGB_temp 임시 이름 변경 완료
#   00020/RGB_real → 00020/RGB 이름 변경 완료
#   00020/RGB_temp → 00020/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00058
#   00058/RGB → 00058/RGB_temp 임시 이름 변경 완료
#   00058/RGB_real → 00058/RGB 이름 변경 완료
#   00058/RGB_temp → 00058/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00100
#   00100/RGB → 00100/RGB_temp 임시 이름 변경 완료
#   00100/RGB_real → 00100/RGB 이름 변경 완료
#   00100/RGB_temp → 00100/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00091
#   00091/RGB → 00091/RGB_temp 임시 이름 변경 완료
#   00091/RGB_real → 00091/RGB 이름 변경 완료
#   00091/RGB_temp → 00091/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00102
#   00102/RGB → 00102/RGB_temp 임시 이름 변경 완료
#   00102/RGB_real → 00102/RGB 이름 변경 완료
#   00102/RGB_temp → 00102/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00017
#   00017/RGB → 00017/RGB_temp 임시 이름 변경 완료
#   00017/RGB_real → 00017/RGB 이름 변경 완료
#   00017/RGB_temp → 00017/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00049
#   00049/RGB → 00049/RGB_temp 임시 이름 변경 완료
#   00049/RGB_real → 00049/RGB 이름 변경 완료
#   00049/RGB_temp → 00049/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00071
#   00071/RGB → 00071/RGB_temp 임시 이름 변경 완료
#   00071/RGB_real → 00071/RGB 이름 변경 완료
#   00071/RGB_temp → 00071/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00022
#   00022/RGB → 00022/RGB_temp 임시 이름 변경 완료
#   00022/RGB_real → 00022/RGB 이름 변경 완료
#   00022/RGB_temp → 00022/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00081
#   00081/RGB → 00081/RGB_temp 임시 이름 변경 완료
#   00081/RGB_real → 00081/RGB 이름 변경 완료
#   00081/RGB_temp → 00081/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00032
#   00032/RGB → 00032/RGB_temp 임시 이름 변경 완료
#   00032/RGB_real → 00032/RGB 이름 변경 완료
#   00032/RGB_temp → 00032/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00002
#   00002/RGB → 00002/RGB_temp 임시 이름 변경 완료
#   00002/RGB_real → 00002/RGB 이름 변경 완료
#   00002/RGB_temp → 00002/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00027
#   00027/RGB → 00027/RGB_temp 임시 이름 변경 완료
#   00027/RGB_real → 00027/RGB 이름 변경 완료
#   00027/RGB_temp → 00027/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00079
#   00079/RGB → 00079/RGB_temp 임시 이름 변경 완료
#   00079/RGB_real → 00079/RGB 이름 변경 완료
#   00079/RGB_temp → 00079/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00092
#   00092/RGB → 00092/RGB_temp 임시 이름 변경 완료
#   00092/RGB_real → 00092/RGB 이름 변경 완료
#   00092/RGB_temp → 00092/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00061
#   00061/RGB → 00061/RGB_temp 임시 이름 변경 완료
#   00061/RGB_real → 00061/RGB 이름 변경 완료
#   00061/RGB_temp → 00061/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00048
#   00048/RGB → 00048/RGB_temp 임시 이름 변경 완료
#   00048/RGB_real → 00048/RGB 이름 변경 완료
#   00048/RGB_temp → 00048/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00055
#   00055/RGB → 00055/RGB_temp 임시 이름 변경 완료
#   00055/RGB_real → 00055/RGB 이름 변경 완료
#   00055/RGB_temp → 00055/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00009
#   00009/RGB → 00009/RGB_temp 임시 이름 변경 완료
#   00009/RGB_real → 00009/RGB 이름 변경 완료
#   00009/RGB_temp → 00009/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00057
#   00057/RGB → 00057/RGB_temp 임시 이름 변경 완료
#   00057/RGB_real → 00057/RGB 이름 변경 완료
#   00057/RGB_temp → 00057/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00053
#   00053/RGB → 00053/RGB_temp 임시 이름 변경 완료
#   00053/RGB_real → 00053/RGB 이름 변경 완료
#   00053/RGB_temp → 00053/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00018
#   00018/RGB → 00018/RGB_temp 임시 이름 변경 완료
#   00018/RGB_real → 00018/RGB 이름 변경 완료
#   00018/RGB_temp → 00018/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00037
#   00037/RGB → 00037/RGB_temp 임시 이름 변경 완료
#   00037/RGB_real → 00037/RGB 이름 변경 완료
#   00037/RGB_temp → 00037/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00082
#   00082/RGB → 00082/RGB_temp 임시 이름 변경 완료
#   00082/RGB_real → 00082/RGB 이름 변경 완료
#   00082/RGB_temp → 00082/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00035
#   00035/RGB → 00035/RGB_temp 임시 이름 변경 완료
#   00035/RGB_real → 00035/RGB 이름 변경 완료
#   00035/RGB_temp → 00035/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00010
#   00010/RGB → 00010/RGB_temp 임시 이름 변경 완료
#   00010/RGB_real → 00010/RGB 이름 변경 완료
#   00010/RGB_temp → 00010/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00015
#   00015/RGB → 00015/RGB_temp 임시 이름 변경 완료
#   00015/RGB_real → 00015/RGB 이름 변경 완료
#   00015/RGB_temp → 00015/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00016
#   00016/RGB → 00016/RGB_temp 임시 이름 변경 완료
#   00016/RGB_real → 00016/RGB 이름 변경 완료
#   00016/RGB_temp → 00016/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00052
#   00052/RGB → 00052/RGB_temp 임시 이름 변경 완료
#   00052/RGB_real → 00052/RGB 이름 변경 완료
#   00052/RGB_temp → 00052/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00019
#   00019/RGB → 00019/RGB_temp 임시 이름 변경 완료
#   00019/RGB_real → 00019/RGB 이름 변경 완료
#   00019/RGB_temp → 00019/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00046
#   00046/RGB → 00046/RGB_temp 임시 이름 변경 완료
#   00046/RGB_real → 00046/RGB 이름 변경 완료
#   00046/RGB_temp → 00046/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00034
#   00034/RGB → 00034/RGB_temp 임시 이름 변경 완료
#   00034/RGB_real → 00034/RGB 이름 변경 완료
#   00034/RGB_temp → 00034/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00024
#   00024/RGB → 00024/RGB_temp 임시 이름 변경 완료
#   00024/RGB_real → 00024/RGB 이름 변경 완료
#   00024/RGB_temp → 00024/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00026
#   00026/RGB → 00026/RGB_temp 임시 이름 변경 완료
#   00026/RGB_real → 00026/RGB 이름 변경 완료
#   00026/RGB_temp → 00026/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00090
#   00090/RGB → 00090/RGB_temp 임시 이름 변경 완료
#   00090/RGB_real → 00090/RGB 이름 변경 완료
#   00090/RGB_temp → 00090/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00036
#   00036/RGB → 00036/RGB_temp 임시 이름 변경 완료
#   00036/RGB_real → 00036/RGB 이름 변경 완료
#   00036/RGB_temp → 00036/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00029
#   00029/RGB → 00029/RGB_temp 임시 이름 변경 완료
#   00029/RGB_real → 00029/RGB 이름 변경 완료
#   00029/RGB_temp → 00029/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00030
#   00030/RGB → 00030/RGB_temp 임시 이름 변경 완료
#   00030/RGB_real → 00030/RGB 이름 변경 완료
#   00030/RGB_temp → 00030/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00001
#   00001/RGB → 00001/RGB_temp 임시 이름 변경 완료
#   00001/RGB_real → 00001/RGB 이름 변경 완료
#   00001/RGB_temp → 00001/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00069
#   00069/RGB → 00069/RGB_temp 임시 이름 변경 완료
#   00069/RGB_real → 00069/RGB 이름 변경 완료
#   00069/RGB_temp → 00069/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00087
#   00087/RGB → 00087/RGB_temp 임시 이름 변경 완료
#   00087/RGB_real → 00087/RGB 이름 변경 완료
#   00087/RGB_temp → 00087/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00093
#   00093/RGB → 00093/RGB_temp 임시 이름 변경 완료
#   00093/RGB_real → 00093/RGB 이름 변경 완료
#   00093/RGB_temp → 00093/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00004
#   00004/RGB → 00004/RGB_temp 임시 이름 변경 완료
#   00004/RGB_real → 00004/RGB 이름 변경 완료
#   00004/RGB_temp → 00004/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00059
#   00059/RGB → 00059/RGB_temp 임시 이름 변경 완료
#   00059/RGB_real → 00059/RGB 이름 변경 완료
#   00059/RGB_temp → 00059/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00047
#   00047/RGB → 00047/RGB_temp 임시 이름 변경 완료
#   00047/RGB_real → 00047/RGB 이름 변경 완료
#   00047/RGB_temp → 00047/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00011
#   00011/RGB → 00011/RGB_temp 임시 이름 변경 완료
#   00011/RGB_real → 00011/RGB 이름 변경 완료
#   00011/RGB_temp → 00011/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00066
#   00066/RGB → 00066/RGB_temp 임시 이름 변경 완료
#   00066/RGB_real → 00066/RGB 이름 변경 완료
#   00066/RGB_temp → 00066/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00065
#   00065/RGB → 00065/RGB_temp 임시 이름 변경 완료
#   00065/RGB_real → 00065/RGB 이름 변경 완료
#   00065/RGB_temp → 00065/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00025
#   00025/RGB → 00025/RGB_temp 임시 이름 변경 완료
#   00025/RGB_real → 00025/RGB 이름 변경 완료
#   00025/RGB_temp → 00025/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00054
#   00054/RGB → 00054/RGB_temp 임시 이름 변경 완료
#   00054/RGB_real → 00054/RGB 이름 변경 완료
#   00054/RGB_temp → 00054/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00060
#   00060/RGB → 00060/RGB_temp 임시 이름 변경 완료
#   00060/RGB_real → 00060/RGB 이름 변경 완료
#   00060/RGB_temp → 00060/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00094
#   00094/RGB → 00094/RGB_temp 임시 이름 변경 완료
#   00094/RGB_real → 00094/RGB 이름 변경 완료
#   00094/RGB_temp → 00094/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00086
#   00086/RGB → 00086/RGB_temp 임시 이름 변경 완료
#   00086/RGB_real → 00086/RGB 이름 변경 완료
#   00086/RGB_temp → 00086/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00068
#   00068/RGB → 00068/RGB_temp 임시 이름 변경 완료
#   00068/RGB_real → 00068/RGB 이름 변경 완료
#   00068/RGB_temp → 00068/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00043
#   00043/RGB → 00043/RGB_temp 임시 이름 변경 완료
#   00043/RGB_real → 00043/RGB 이름 변경 완료
#   00043/RGB_temp → 00043/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00040
#   00040/RGB → 00040/RGB_temp 임시 이름 변경 완료
#   00040/RGB_real → 00040/RGB 이름 변경 완료
#   00040/RGB_temp → 00040/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00076
#   00076/RGB → 00076/RGB_temp 임시 이름 변경 완료
#   00076/RGB_real → 00076/RGB 이름 변경 완료
#   00076/RGB_temp → 00076/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00072
#   00072/RGB → 00072/RGB_temp 임시 이름 변경 완료
#   00072/RGB_real → 00072/RGB 이름 변경 완료
#   00072/RGB_temp → 00072/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00007
#   00007/RGB → 00007/RGB_temp 임시 이름 변경 완료
#   00007/RGB_real → 00007/RGB 이름 변경 완료
#   00007/RGB_temp → 00007/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00039
#   00039/RGB → 00039/RGB_temp 임시 이름 변경 완료
#   00039/RGB_real → 00039/RGB 이름 변경 완료
#   00039/RGB_temp → 00039/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00078
#   00078/RGB → 00078/RGB_temp 임시 이름 변경 완료
#   00078/RGB_real → 00078/RGB 이름 변경 완료
#   00078/RGB_temp → 00078/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00099
#   00099/RGB → 00099/RGB_temp 임시 이름 변경 완료
#   00099/RGB_real → 00099/RGB 이름 변경 완료
#   00099/RGB_temp → 00099/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00096
#   00096/RGB → 00096/RGB_temp 임시 이름 변경 완료
#   00096/RGB_real → 00096/RGB 이름 변경 완료
#   00096/RGB_temp → 00096/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00088
#   00088/RGB → 00088/RGB_temp 임시 이름 변경 완료
#   00088/RGB_real → 00088/RGB 이름 변경 완료
#   00088/RGB_temp → 00088/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00031
#   00031/RGB → 00031/RGB_temp 임시 이름 변경 완료
#   00031/RGB_real → 00031/RGB 이름 변경 완료
#   00031/RGB_temp → 00031/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00098
#   00098/RGB → 00098/RGB_temp 임시 이름 변경 완료
#   00098/RGB_real → 00098/RGB 이름 변경 완료
#   00098/RGB_temp → 00098/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00008
#   00008/RGB → 00008/RGB_temp 임시 이름 변경 완료
#   00008/RGB_real → 00008/RGB 이름 변경 완료
#   00008/RGB_temp → 00008/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00014
#   00014/RGB → 00014/RGB_temp 임시 이름 변경 완료
#   00014/RGB_real → 00014/RGB 이름 변경 완료
#   00014/RGB_temp → 00014/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00062
#   00062/RGB → 00062/RGB_temp 임시 이름 변경 완료
#   00062/RGB_real → 00062/RGB 이름 변경 완료
#   00062/RGB_temp → 00062/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00003
#   00003/RGB → 00003/RGB_temp 임시 이름 변경 완료
#   00003/RGB_real → 00003/RGB 이름 변경 완료
#   00003/RGB_temp → 00003/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00080
#   00080/RGB → 00080/RGB_temp 임시 이름 변경 완료
#   00080/RGB_real → 00080/RGB 이름 변경 완료
#   00080/RGB_temp → 00080/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00084
#   00084/RGB → 00084/RGB_temp 임시 이름 변경 완료
#   00084/RGB_real → 00084/RGB 이름 변경 완료
#   00084/RGB_temp → 00084/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00005
#   00005/RGB → 00005/RGB_temp 임시 이름 변경 완료
#   00005/RGB_real → 00005/RGB 이름 변경 완료
#   00005/RGB_temp → 00005/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00033
#   00033/RGB → 00033/RGB_temp 임시 이름 변경 완료
#   00033/RGB_real → 00033/RGB 이름 변경 완료
#   00033/RGB_temp → 00033/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00006
#   00006/RGB → 00006/RGB_temp 임시 이름 변경 완료
#   00006/RGB_real → 00006/RGB 이름 변경 완료
#   00006/RGB_temp → 00006/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00095
#   00095/RGB → 00095/RGB_temp 임시 이름 변경 완료
#   00095/RGB_real → 00095/RGB 이름 변경 완료
#   00095/RGB_temp → 00095/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00077
#   00077/RGB → 00077/RGB_temp 임시 이름 변경 완료
#   00077/RGB_real → 00077/RGB 이름 변경 완료
#   00077/RGB_temp → 00077/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00028
#   00028/RGB → 00028/RGB_temp 임시 이름 변경 완료
#   00028/RGB_real → 00028/RGB 이름 변경 완료
#   00028/RGB_temp → 00028/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00050
#   00050/RGB → 00050/RGB_temp 임시 이름 변경 완료
#   00050/RGB_real → 00050/RGB 이름 변경 완료
#   00050/RGB_temp → 00050/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00074
#   00074/RGB → 00074/RGB_temp 임시 이름 변경 완료
#   00074/RGB_real → 00074/RGB 이름 변경 완료
#   00074/RGB_temp → 00074/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00013
#   00013/RGB → 00013/RGB_temp 임시 이름 변경 완료
#   00013/RGB_real → 00013/RGB 이름 변경 완료
#   00013/RGB_temp → 00013/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00067
#   00067/RGB → 00067/RGB_temp 임시 이름 변경 완료
#   00067/RGB_real → 00067/RGB 이름 변경 완료
#   00067/RGB_temp → 00067/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00023
#   00023/RGB → 00023/RGB_temp 임시 이름 변경 완료
#   00023/RGB_real → 00023/RGB 이름 변경 완료
#   00023/RGB_temp → 00023/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00051
#   00051/RGB → 00051/RGB_temp 임시 이름 변경 완료
#   00051/RGB_real → 00051/RGB 이름 변경 완료
#   00051/RGB_temp → 00051/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00021
#   00021/RGB → 00021/RGB_temp 임시 이름 변경 완료
#   00021/RGB_real → 00021/RGB 이름 변경 완료
#   00021/RGB_temp → 00021/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00089
#   00089/RGB → 00089/RGB_temp 임시 이름 변경 완료
#   00089/RGB_real → 00089/RGB 이름 변경 완료
#   00089/RGB_temp → 00089/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00041
#   00041/RGB → 00041/RGB_temp 임시 이름 변경 완료
#   00041/RGB_real → 00041/RGB 이름 변경 완료
#   00041/RGB_temp → 00041/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00073
#   00073/RGB → 00073/RGB_temp 임시 이름 변경 완료
#   00073/RGB_real → 00073/RGB 이름 변경 완료
#   00073/RGB_temp → 00073/RGB2GRAY 이름 변경 완료
# 폴더 처리 중: 00056
#   00056/RGB → 00056/RGB_temp 임시 이름 변경 완료
#   00056/RGB_real → 00056/RGB 이름 변경 완료
#   00056/RGB_temp → 00056/RGB2GRAY 이름 변경 완료
# 모든 폴더 원상복구 완료

# %%
import cv2
import os

def extract_frames(video_path, output_dir, start_time=20, end_time=25, interval_seconds=5):
    """
    동영상에서 특정 구간의 프레임을 지정된 시간 간격으로 추출하여 저장
    :param video_path: 동영상 파일 경로
    :param output_dir: 프레임을 저장할 디렉토리
    :param start_time: 분 단위 시작 시간 (기본: 20분)
    :param end_time: 분 단위 종료 시간 (기본: 25분)
    :param interval_seconds: 프레임 추출 간격 (초) (기본: 5초)
    """
    # 디버깅 정보 출력
    print(f"비디오 경로: {video_path}")
    print(f"출력 디렉토리: {output_dir}")
    print(f"시작 시간: {start_time}분, 종료 시간: {end_time}분")
    print(f"추출 간격: {interval_seconds}초")
    
    # 비디오 파일 존재 확인
    if not os.path.exists(video_path):
        print(f"오류: 비디오 파일이 존재하지 않습니다: {video_path}")
        return
    
    os.makedirs(output_dir, exist_ok=True)

    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"오류: 비디오 파일을 열 수 없습니다: {video_path}")
        return
        
    # 비디오 정보 확인
    video_fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    video_duration = total_frames / video_fps / 60  # 분 단위
    
    print(f"비디오 FPS: {video_fps}")
    print(f"총 프레임 수: {total_frames}")
    print(f"비디오 길이: {video_duration:.2f}분")
    
    # 시작 및 종료 프레임 계산 (분 단위 입력을 초 단위로 변환)
    start_frame = int(start_time * 60 * video_fps)
    end_frame = int(end_time * 60 * video_fps)
    frame_interval = int(video_fps * interval_seconds)
    
    print(f"시작 프레임: {start_frame}, 종료 프레임: {end_frame}")
    print(f"프레임 간격: {frame_interval}")
    
    # 유효성 검사
    if start_frame >= total_frames:
        print("오류: 시작 시간이 비디오 길이를 초과합니다.")
        return
    if end_frame >= total_frames:
        print(f"경고: 종료 시간이 비디오 길이를 초과합니다. 마지막 프레임({total_frames})으로 조정합니다.")
        end_frame = total_frames - 1

    cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)  # 시작 지점 설정

    frame_idx = start_frame
    saved_frame_idx = 0

    while cap.isOpened() and frame_idx <= end_frame:
        ret, frame = cap.read()
        if not ret:
            print(f"프레임 {frame_idx} 읽기 실패")
            break  # 동영상 끝

        if (frame_idx - start_frame) % frame_interval == 0:
            frame_path = os.path.join(output_dir, f"frame_{saved_frame_idx:05d}.jpg")
            cv2.imwrite(frame_path, frame)
            saved_frame_idx += 1
            print(f"프레임 저장: {frame_path}")
            
            # 다음 프레임으로 점프 (interval_seconds초 건너뛰기)
            next_frame = frame_idx + frame_interval
            if next_frame <= end_frame:
                cap.set(cv2.CAP_PROP_POS_FRAMES, next_frame)
                frame_idx = next_frame
                continue

        frame_idx += 1

    cap.release()
    print(f"총 {saved_frame_idx}개 프레임 추출 완료 (시간 범위: {start_time}분-{end_time}분, 간격: {interval_seconds}초)")

# 사용 예시
data_path_ori = os.path.abspath("/tf/00_data/#_2021_Sleep_Video")
video_id = "A2019-EM-01-0008"
data_path = '/tf/02_code/SLP-Dataset-and-Code/data/KISS/images'
output_path = os.path.join(data_path, video_id)
video_path = os.path.join(data_path_ori, video_id, f"{video_id}_video_01.mp4")

# 디버깅을 위해 파일 존재 확인
print(f"최종 비디오 경로: {video_path}")
print(f"파일 존재 여부: {os.path.exists(video_path)}")

extract_frames(video_path, output_path, start_time=30, end_time=40, interval_seconds=5)
# Out:
# 최종 비디오 경로: /tf/00_data/#_2021_Sleep_Video/A2019-EM-01-0008/A2019-EM-01-0008_video_01.mp4
# 파일 존재 여부: True
# 비디오 경로: /tf/00_data/#_2021_Sleep_Video/A2019-EM-01-0008/A2019-EM-01-0008_video_01.mp4
# 출력 디렉토리: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008
# 시작 시간: 30분, 종료 시간: 40분
# 추출 간격: 5초
# 비디오 FPS: 4
# 총 프레임 수: 94856
# 비디오 길이: 395.23분
# 시작 프레임: 7200, 종료 프레임: 9600
# 프레임 간격: 20
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00000.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00001.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00002.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00003.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00004.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00005.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00006.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00007.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00008.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00009.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00010.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00011.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00012.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00013.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00014.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00015.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00016.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00017.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00018.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00019.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00020.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00021.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00022.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00023.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00024.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00025.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00026.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00027.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00028.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00029.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00030.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00031.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00032.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00033.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00034.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00035.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00036.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00037.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00038.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00039.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00040.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00041.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00042.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00043.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00044.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00045.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00046.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00047.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00048.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00049.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00050.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00051.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00052.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00053.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00054.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00055.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00056.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00057.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00058.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00059.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00060.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00061.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00062.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00063.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00064.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00065.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00066.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00067.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00068.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00069.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00070.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00071.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00072.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00073.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00074.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00075.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00076.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00077.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00078.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00079.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00080.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00081.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00082.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00083.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00084.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00085.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00086.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00087.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00088.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00089.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00090.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00091.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00092.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00093.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00094.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00095.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00096.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00097.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00098.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00099.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00100.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00101.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00102.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00103.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00104.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00105.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00106.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00107.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00108.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00109.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00110.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00111.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00112.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00113.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00114.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00115.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00116.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00117.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00118.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00119.jpg
# 프레임 저장: /tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00120.jpg
# 총 121개 프레임 추출 완료 (시간 범위: 30분-40분, 간격: 5초)

# %%
img = cv2.imread('/tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00121.png')
cv2.imwrite('/tf/02_code/SLP-Dataset-and-Code/data/KISS/images/A2019-EM-01-0008/frame_00121.jpg', img)
# Out:
# True
